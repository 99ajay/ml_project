# %% [markdown]
# # Quick overview of the dataset :

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns=[features]
# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.head()
# Out:
#   tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 0          0.288585         -0.020294         -0.132905        -0.995279
# 1          0.278419         -0.016411         -0.123520        -0.998245
# 2          0.279653         -0.019467         -0.113462        -0.995380
# 3          0.279174         -0.026201         -0.123283        -0.996091
# 4          0.276629         -0.016570         -0.115362        -0.998139
#
#   tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 0        -0.983111        -0.913526        -0.995112        -0.983185
# 1        -0.975300        -0.960322        -0.998807        -0.974914
# 2        -0.967187        -0.978944        -0.996520        -0.963668
# 3        -0.983403        -0.990675        -0.997099        -0.982750
# 4        -0.980817        -0.990482        -0.998321        -0.979672
#
#   tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 0        -0.923527        -0.934724  ...                   -0.112754
# 1        -0.957686        -0.943068  ...                    0.053477
# 2        -0.977469        -0.938692  ...                   -0.118559
# 3        -0.989302        -0.938692  ...                   -0.036788
# 4        -0.990441        -0.942469  ...                    0.123320
#
#   angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 0                             0.030400                        -0.464761
# 1                            -0.007435                        -0.732626
# 2                             0.177899                         0.100699
# 3                            -0.012892                         0.640011
# 4                             0.122542                         0.693578
#
#   angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 0                            -0.018446            -0.841247
# 1                             0.703511            -0.844788
# 2                             0.808529            -0.848933
# 3                            -0.485366            -0.848649
# 4                            -0.615971            -0.847865
#
#   angle(Y,gravityMean) angle(Z,gravityMean) subject Activity ActivityName
# 0             0.179941            -0.058627       1        5     STANDING
# 1             0.180289            -0.054317       1        5     STANDING
# 2             0.180637            -0.049118       1        5     STANDING
# 3             0.181935            -0.047663       1        5     STANDING
# 4             0.185151            -0.043892       1        5     STANDING
#
# [5 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns=[features]
# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 1321          0.323208         -0.029482         -0.116846        -0.161887
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 1321        -0.219879        -0.375113        -0.211989        -0.296217
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 1321        -0.383367          0.08137  ...                   -0.698362
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 1321                             -0.63598                         0.993963
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 1321                             0.040409            -0.826732
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Activity  \
# 1321             0.200865              0.08193      12        3
#
#             ActivityName
# 1321  WALKING_DOWNSTAIRS
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2940: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False) 
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)
train = pd.read_csv('UCI_HAR_dataset/csv_files/train.csv')
test = pd.read_csv('UCI_HAR_dataset/csv_files/test.csv')
print(train.shape, test.shape)
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test
# (7352, 564) (2947, 564)

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=40)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

#train.columns
# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# <ipython-input-11-73b60e3fb5a2>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[()]','')
# <ipython-input-11-73b60e3fb5a2>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[-]', '')
# <ipython-input-11-73b60e3fb5a2>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[,]','')
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)
train.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
# 2                 -0.118559                          0.177899
# 3                 -0.036788                         -0.012892
# 4                  0.123320                          0.122542
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
# 2                       0.100699                           0.808529
# 3                       0.640011                          -0.485366
# 4                       0.693578                          -0.615971
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  Activity  \
# 0          -0.841247           0.179941          -0.058627        1         5
# 1          -0.844788           0.180289          -0.054317        1         5
# 2          -0.848933           0.180637          -0.049118        1         5
# 3          -0.848649           0.181935          -0.047663        1         5
# 4          -0.847865           0.185151          -0.043892        1         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
# 2      STANDING
# 3      STANDING
# 4      STANDING
#
# [5 rows x 564 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', height=5,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.960,12), xytext=(-0.5, 15), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
               
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# [t-SNE] Computed neighbors for 7352 samples in 1.554s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.016s
# [t-SNE] Iteration 50: error = 124.6948929, gradient norm = 0.0284036 (50 iterations in 5.451s)
# [t-SNE] Iteration 100: error = 106.8321457, gradient norm = 0.0279449 (50 iterations in 2.962s)
# [t-SNE] Iteration 150: error = 100.6650238, gradient norm = 0.0226766 (50 iterations in 2.487s)
# [t-SNE] Iteration 200: error = 97.3123245, gradient norm = 0.0196593 (50 iterations in 2.173s)
# [t-SNE] Iteration 250: error = 95.0491257, gradient norm = 0.0128200 (50 iterations in 2.255s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.049126
# [t-SNE] Iteration 300: error = 4.1147041, gradient norm = 0.0015610 (50 iterations in 2.093s)
# [t-SNE] Iteration 350: error = 3.2082729, gradient norm = 0.0010102 (50 iterations in 1.880s)
# [t-SNE] Iteration 400: error = 2.7802646, gradient norm = 0.0007154 (50 iterations in 1.867s)
# [t-SNE] Iteration 450: error = 2.5162833, gradient norm = 0.0005695 (50 iterations in 2.072s)
# [t-SNE] Iteration 500: error = 2.3333440, gradient norm = 0.0004738 (50 iterations in 2.065s)
# [t-SNE] Iteration 550: error = 2.1955187, gradient norm = 0.0004176 (50 iterations in 2.031s)
# [t-SNE] Iteration 600: error = 2.0860445, gradient norm = 0.0003691 (50 iterations in 1.986s)
# [t-SNE] Iteration 650: error = 1.9966125, gradient norm = 0.0003274 (50 iterations in 2.173s)
# [t-SNE] Iteration 700: error = 1.9209623, gradient norm = 0.0002993 (50 iterations in 2.265s)
# [t-SNE] Iteration 750: error = 1.8558052, gradient norm = 0.0002785 (50 iterations in 2.260s)
# [t-SNE] Iteration 800: error = 1.7992156, gradient norm = 0.0002593 (50 iterations in 2.230s)
# [t-SNE] Iteration 850: error = 1.7492347, gradient norm = 0.0002370 (50 iterations in 2.188s)
# [t-SNE] Iteration 900: error = 1.7046731, gradient norm = 0.0002243 (50 iterations in 2.237s)
# [t-SNE] Iteration 950: error = 1.6644961, gradient norm = 0.0002105 (50 iterations in 2.377s)
# [t-SNE] Iteration 1000: error = 1.6281788, gradient norm = 0.0001985 (50 iterations in 2.236s)
# [t-SNE] KL divergence after 1000 iterations: 1.628179
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# [t-SNE] Computed neighbors for 7352 samples in 1.644s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.045s
# [t-SNE] Iteration 50: error = 114.1591949, gradient norm = 0.0192138 (50 iterations in 3.310s)
# [t-SNE] Iteration 100: error = 97.5347595, gradient norm = 0.0153362 (50 iterations in 2.307s)
# [t-SNE] Iteration 150: error = 93.1152954, gradient norm = 0.0103625 (50 iterations in 2.103s)
# [t-SNE] Iteration 200: error = 91.1602173, gradient norm = 0.0064231 (50 iterations in 2.058s)
# [t-SNE] Iteration 250: error = 90.0018387, gradient norm = 0.0052968 (50 iterations in 2.074s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.001839
# [t-SNE] Iteration 300: error = 3.5729475, gradient norm = 0.0014653 (50 iterations in 2.005s)
# [t-SNE] Iteration 350: error = 2.8144410, gradient norm = 0.0007491 (50 iterations in 2.044s)
# [t-SNE] Iteration 400: error = 2.4338346, gradient norm = 0.0005311 (50 iterations in 2.073s)
# [t-SNE] Iteration 450: error = 2.2166653, gradient norm = 0.0004068 (50 iterations in 2.120s)
# [t-SNE] Iteration 500: error = 2.0720096, gradient norm = 0.0003310 (50 iterations in 2.148s)
# [t-SNE] Iteration 550: error = 1.9665262, gradient norm = 0.0002874 (50 iterations in 2.150s)
# [t-SNE] Iteration 600: error = 1.8853347, gradient norm = 0.0002461 (50 iterations in 2.246s)
# [t-SNE] Iteration 650: error = 1.8203930, gradient norm = 0.0002203 (50 iterations in 2.050s)
# [t-SNE] Iteration 700: error = 1.7668417, gradient norm = 0.0001973 (50 iterations in 2.058s)
# [t-SNE] Iteration 750: error = 1.7215575, gradient norm = 0.0001809 (50 iterations in 2.132s)
# [t-SNE] Iteration 800: error = 1.6826893, gradient norm = 0.0001670 (50 iterations in 2.159s)
# [t-SNE] Iteration 850: error = 1.6490021, gradient norm = 0.0001535 (50 iterations in 2.118s)
# [t-SNE] Iteration 900: error = 1.6192248, gradient norm = 0.0001407 (50 iterations in 2.181s)
# [t-SNE] Iteration 950: error = 1.5928068, gradient norm = 0.0001340 (50 iterations in 2.261s)
# [t-SNE] Iteration 1000: error = 1.5689690, gradient norm = 0.0001260 (50 iterations in 2.054s)
# [t-SNE] KL divergence after 1000 iterations: 1.568969
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# [t-SNE] Computed neighbors for 7352 samples in 1.535s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.094s
# [t-SNE] Iteration 50: error = 105.5787201, gradient norm = 0.0211806 (50 iterations in 2.814s)
# [t-SNE] Iteration 100: error = 90.1892548, gradient norm = 0.0124885 (50 iterations in 2.371s)
# [t-SNE] Iteration 150: error = 87.2537308, gradient norm = 0.0060067 (50 iterations in 2.291s)
# [t-SNE] Iteration 200: error = 86.0362167, gradient norm = 0.0042288 (50 iterations in 2.242s)
# [t-SNE] Iteration 250: error = 85.3494720, gradient norm = 0.0041619 (50 iterations in 2.187s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.349472
# [t-SNE] Iteration 300: error = 3.1338637, gradient norm = 0.0013919 (50 iterations in 2.207s)
# [t-SNE] Iteration 350: error = 2.4902782, gradient norm = 0.0006515 (50 iterations in 2.257s)
# [t-SNE] Iteration 400: error = 2.1718516, gradient norm = 0.0004226 (50 iterations in 2.316s)
# [t-SNE] Iteration 450: error = 1.9876906, gradient norm = 0.0003134 (50 iterations in 2.201s)
# [t-SNE] Iteration 500: error = 1.8697907, gradient norm = 0.0002509 (50 iterations in 2.263s)
# [t-SNE] Iteration 550: error = 1.7866213, gradient norm = 0.0002127 (50 iterations in 2.455s)
# [t-SNE] Iteration 600: error = 1.7241770, gradient norm = 0.0001810 (50 iterations in 2.438s)
# [t-SNE] Iteration 650: error = 1.6753556, gradient norm = 0.0001605 (50 iterations in 2.158s)
# [t-SNE] Iteration 700: error = 1.6361778, gradient norm = 0.0001438 (50 iterations in 2.263s)
# [t-SNE] Iteration 750: error = 1.6033911, gradient norm = 0.0001292 (50 iterations in 2.217s)
# [t-SNE] Iteration 800: error = 1.5757085, gradient norm = 0.0001189 (50 iterations in 2.219s)
# [t-SNE] Iteration 850: error = 1.5517921, gradient norm = 0.0001097 (50 iterations in 2.234s)
# [t-SNE] Iteration 900: error = 1.5313842, gradient norm = 0.0001024 (50 iterations in 2.286s)
# [t-SNE] Iteration 950: error = 1.5138488, gradient norm = 0.0000971 (50 iterations in 2.165s)
# [t-SNE] Iteration 1000: error = 1.4985223, gradient norm = 0.0000901 (50 iterations in 2.171s)
# [t-SNE] KL divergence after 1000 iterations: 1.498522
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.000s...
# [t-SNE] Computed neighbors for 7352 samples in 1.648s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.180s
# [t-SNE] Iteration 50: error = 97.5551453, gradient norm = 0.0158582 (50 iterations in 3.058s)
# [t-SNE] Iteration 100: error = 84.2071304, gradient norm = 0.0064174 (50 iterations in 2.539s)
# [t-SNE] Iteration 150: error = 81.9959488, gradient norm = 0.0042565 (50 iterations in 2.545s)
# [t-SNE] Iteration 200: error = 81.2071838, gradient norm = 0.0036895 (50 iterations in 2.464s)
# [t-SNE] Iteration 250: error = 80.7726898, gradient norm = 0.0021566 (50 iterations in 2.515s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.772690
# [t-SNE] Iteration 300: error = 2.7021079, gradient norm = 0.0013072 (50 iterations in 2.454s)
# [t-SNE] Iteration 350: error = 2.1659162, gradient norm = 0.0005787 (50 iterations in 2.462s)
# [t-SNE] Iteration 400: error = 1.9162469, gradient norm = 0.0003479 (50 iterations in 2.488s)
# [t-SNE] Iteration 450: error = 1.7701499, gradient norm = 0.0002483 (50 iterations in 2.555s)
# [t-SNE] Iteration 500: error = 1.6765920, gradient norm = 0.0001935 (50 iterations in 2.519s)
# [t-SNE] Iteration 550: error = 1.6125040, gradient norm = 0.0001581 (50 iterations in 2.846s)
# [t-SNE] Iteration 600: error = 1.5656137, gradient norm = 0.0001364 (50 iterations in 2.951s)
# [t-SNE] Iteration 650: error = 1.5303485, gradient norm = 0.0001164 (50 iterations in 2.749s)
# [t-SNE] Iteration 700: error = 1.5027630, gradient norm = 0.0001050 (50 iterations in 2.763s)
# [t-SNE] Iteration 750: error = 1.4804910, gradient norm = 0.0000947 (50 iterations in 3.025s)
# [t-SNE] Iteration 800: error = 1.4623027, gradient norm = 0.0000873 (50 iterations in 2.647s)
# [t-SNE] Iteration 850: error = 1.4474037, gradient norm = 0.0000810 (50 iterations in 2.633s)
# [t-SNE] Iteration 900: error = 1.4349840, gradient norm = 0.0000753 (50 iterations in 2.551s)
# [t-SNE] Iteration 950: error = 1.4243934, gradient norm = 0.0000716 (50 iterations in 2.476s)
# [t-SNE] Iteration 1000: error = 1.4155895, gradient norm = 0.0000696 (50 iterations in 2.492s)
# [t-SNE] KL divergence after 1000 iterations: 1.415589
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.019s...
# [t-SNE] Computed neighbors for 7352 samples in 1.632s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.435s
# [t-SNE] Iteration 50: error = 86.0583801, gradient norm = 0.0242909 (50 iterations in 3.890s)
# [t-SNE] Iteration 100: error = 76.0769958, gradient norm = 0.0048549 (50 iterations in 4.198s)
# [t-SNE] Iteration 150: error = 74.9871063, gradient norm = 0.0027557 (50 iterations in 4.485s)
# [t-SNE] Iteration 200: error = 74.5131607, gradient norm = 0.0016126 (50 iterations in 4.480s)
# [t-SNE] Iteration 250: error = 74.2861404, gradient norm = 0.0011861 (50 iterations in 3.998s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.286140
# [t-SNE] Iteration 300: error = 2.1943021, gradient norm = 0.0012088 (50 iterations in 3.486s)
# [t-SNE] Iteration 350: error = 1.7881944, gradient norm = 0.0004967 (50 iterations in 3.215s)
# [t-SNE] Iteration 400: error = 1.6137153, gradient norm = 0.0002887 (50 iterations in 3.265s)
# [t-SNE] Iteration 450: error = 1.5162982, gradient norm = 0.0001990 (50 iterations in 3.281s)
# [t-SNE] Iteration 500: error = 1.4531972, gradient norm = 0.0001471 (50 iterations in 3.274s)
# [t-SNE] Iteration 550: error = 1.4095373, gradient norm = 0.0001168 (50 iterations in 3.330s)
# [t-SNE] Iteration 600: error = 1.3779218, gradient norm = 0.0000988 (50 iterations in 3.259s)
# [t-SNE] Iteration 650: error = 1.3548697, gradient norm = 0.0000856 (50 iterations in 3.282s)
# [t-SNE] Iteration 700: error = 1.3376627, gradient norm = 0.0000798 (50 iterations in 3.302s)
# [t-SNE] Iteration 750: error = 1.3243840, gradient norm = 0.0000758 (50 iterations in 3.626s)
# [t-SNE] Iteration 800: error = 1.3138086, gradient norm = 0.0000661 (50 iterations in 3.360s)
# [t-SNE] Iteration 850: error = 1.3057095, gradient norm = 0.0000617 (50 iterations in 3.253s)
# [t-SNE] Iteration 900: error = 1.2988031, gradient norm = 0.0000572 (50 iterations in 3.225s)
# [t-SNE] Iteration 950: error = 1.2930773, gradient norm = 0.0000534 (50 iterations in 3.312s)
# [t-SNE] Iteration 1000: error = 1.2881194, gradient norm = 0.0000511 (50 iterations in 3.324s)
# [t-SNE] KL divergence after 1000 iterations: 1.288119
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
